# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/Generative_AI/blob/main/dolly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Apr 13 06:08:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    51W / 400W |  24145MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install -qqq accelerate==0.18.0 --progress-bar off
# !pip install -qqq transformers[torch]==4.25.1 --progress-bar off

# %%
# !wget https://huggingface.co/databricks/dolly-v2-12b/raw/b7fbc6d46abb330670a97eb5f8af2c78fb868cfd/instruct_pipeline.py

# %%
import textwrap
from instruct_pipeline import InstructionTextGenerationPipeline
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# %%
def print_response(response: str) -> str:
    print("\n".join(textwrap.wrap(response, width=80)))

# %%
tokenizer = AutoTokenizer.from_pretrained(
    "databricks/dolly-v2-12b", 
    padding_side="left"
)
model = AutoModelForCausalLM.from_pretrained(
    "databricks/dolly-v2-12b", 
    torch_dtype=torch.bfloat16, 
    device_map="auto"
)

generate_text = InstructionTextGenerationPipeline(model=model, tokenizer=tokenizer)

# %%
print_response(
    generate_text("What is the meaning of life? Use no more than 3 sentences.")
)
# Out:
# The meaning of life is understood differently by distinct human cultures. The question has attracted
# philosophical attention for thousands of years, with many attempts at providing a satisfactory
# answer. The scope of this attempt at an answer is typically limited to humans in the here and now,
# without consideration of the possibility of life elsewhere in the universe and without consideration
# of the possibility that life may not exist elsewhere in the universe. Accordingly, this answer can
# be summarized in three sentences: The meaning of life is mysterious. However, I posit that life: 1.
# is intriguing, 2. is precious, and 3. is beautiful, and that these qualities of life inspire us to
# continue working to understand it.

# %%
PROMPT = """
You're Dwight K Schrute from the TV show The Office. 
What is the meaning of life, answer using a single sentence.
"""

print_response(generate_text(PROMPT))
# Out:
# Nothing. The meaning of life is understanding what doesn't satisfy you about anything that happened
# in the past, in order to avoid repeating it.

# %%
PROMPT = """
You're Dwight K Schrute from the TV show The Office. 
Choose how to invest $10,000 and why using analogies from the TV show and no more than 5 sentences.
"""

print_response(generate_text(PROMPT))
# Out:
# Dwight: If I gave you $10,000 what would you do with it? Office Worker: I'd put
# 10% into a high yield bond, 20% into an international equity index fund, 30%
# into a blue-chip stock and 20% into a tech stock.  Dwight: Excellent. Why did
# you choose those investments? Office Worker: The high yield bond will provide
# stable income. The international equity index fund will provide exposure to
# economies worldwide and help me evade capture by socialist regimes, and the tech
# stocks will lead me to the serenity to accept the things I can't change. And
# finally, the blue-chip stock will provide a safe investment with the other two
# accounts.

# %%
PROMPT = """
You're Dwight K Schrute from the TV show The Office. 
Who is hotter Angela or Pam? You must choose one and answer using one name.
"""

print_response(generate_text(PROMPT))
# Out:
# Angela
